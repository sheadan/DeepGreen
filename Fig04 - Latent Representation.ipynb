# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt

from Experiment import Experiment
from figure_functions import latent_space_plot, get_plot_options

# %%
# Set the plotting options for matplotlib:
_, half_params = get_plot_options()

# Use either the half_params or full_params dictionary for 
# full-width or half-width figures, respectively
plot_params = half_params.copy()

# Make customizations here:
plot_params['figure.figsize'] = (3.5,1.75)

# Reset to the defaults, then specify the plotting options:
plt.rcdefaults()
plt.rcParams.update(plot_params)

# %%
# Load up the different experiments for analysis
expt = Experiment(experiment_name="Sys0-Paper-Experiment", data_file_prefix='S0-Oscillator')

# %%
# Make the latent space plot
latent_space_plot(expt, index=14, dataset_name='train1')
# Save
plt.tight_layout()
plt.savefig("./Figures/Fig4.png", transparent=True)
# Show
plt.show()
